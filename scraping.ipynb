# %%
import pandas as pd

df = pd.read_csv('./anilist-users-list.csv')

# %%
print('data duplikasi =', df.duplicated().sum())

print('menghapus data duplikasi jika ada................')
df = df.drop_duplicates()

print('data duplikasi setelah dibersihkan =', df.duplicated().sum())
# Out:
# data duplikasi = 0
# menghapus data duplikasi jika ada................
# data duplikasi setelah dibersihkan = 0

# %%
import requests
import time

async def fetch_usernames(anime_id):
  hasNextPage = True
  i = 1
  names = []
  while hasNextPage == True:
    query = '''
    query getUsernames($id: Int, $page: Int){
      Media(id: $id) {
        reviews(page: $page) {
          pageInfo {
            hasNextPage
          }
          nodes {
            user {
              name
            }
          }
        }
      }
    }
    '''

    variables = {
        'id': anime_id,
        'page' : i
    }

    payload = {
        "query": query,
        "variables": variables
    }

    response = requests.post(url='https://graphql.anilist.co', json=payload)

    if response.status_code == 429:
      print('Rate limit exceeded while fetching usernames, Sleeping rn')
      time.sleep(int(response.headers['Retry-After']) + 1)
      return await fetch_usernames(anime_id)

    if response.status_code != 200:
        print(f"Error: {response.status_code}, {response.text}")

    names.extend([review['user']['name'] for review in response.json()['data']['Media']['reviews']['nodes']])
    hasNextPage = response.json()['data']['Media']['reviews']['pageInfo']['hasNextPage']
    i += 1

  return names

# %%
import requests
import time

async def fetch_anime_list(username):
  query = '''
  query getAnimeList($userName: String){
    MediaListCollection(userName: $userName, type: ANIME, status: COMPLETED) {
      lists {
        entries {
          media {
            id
            genres
          }
          score
        }
      }
    }
  }
  '''

  variables = {
      'userName': username
  }

  payload = {
      "query": query,
      "variables": variables
  }

  response = requests.post(url='https://graphql.anilist.co', json=payload)

  if response.status_code == 429:
      print('Rate limit exceeded while fetching anime list, Sleeping rn')
      time.sleep(int(response.headers['Retry-After']) + 1)
      return await fetch_anime_list(username)

  if response.status_code != 200:
      print(f"Error: {response.status_code}, {response.text}")
      return []

  if len(response.json()["data"]["MediaListCollection"]["lists"]) == 0:
    return []

  return response.json()["data"]["MediaListCollection"]["lists"][0]['entries']

# %%
import pandas as pd

def get_average_score(medias, username, min):
  print('Calculating average score by user', username, 'with', len(medias), 'of animes', end=" ")
  if len(medias) < min:
    print('................> Aborted (Too few animes)')
    return pd.DataFrame()

  genre_totals = {}
  genre_counts = {}

  # Iterate through the data
  for entry in medias:
      genres = entry['media']['genres']
      score = entry['score']

      for genre in genres:
          if genre in genre_totals:
              genre_totals[genre] += score
              genre_counts[genre] += 1
          else:
              genre_totals[genre] = score
              genre_counts[genre] = 1

  # Calculate average score for each genre
  genre_averages = {genre: genre_totals[genre] / genre_counts[genre]
                    if genre_totals[genre] / genre_counts[genre] <= 10
                    else (genre_totals[genre] / genre_counts[genre])/10
                    for genre in genre_totals}

  # Print the results
  genre_averages['username'] = username

  print('................> Success')
  return pd.DataFrame([genre_averages])

# %%
import pandas as pd

async def start_scraping(anime_ids, min_anime_per_user):
  df_columns = [
      "username",
      "Action", "Adventure", "Comedy", "Drama", "Ecchi",
      "Fantasy", "Hentai", "Horror", "Mahou Shoujo", "Mecha",
      "Music", "Mystery", "Psychological", "Romance", "Sci-Fi",
      "Slice of Life", "Sports", "Supernatural", "Thriller"
  ]
  df = pd.DataFrame(columns=df_columns)
  df

  print('Scraping from', len(anime_ids), 'animes, with minimum', min_anime_per_user, 'anime per user')
  for anime_id in anime_ids:
    names = await fetch_usernames(anime_id)
    for name in names:
      if name in df['username'].values:
        print('username already scraped, continuing................')
        continue
      anime_list = await fetch_anime_list(name)
      average_score = get_average_score(anime_list, name, min_anime_per_user)
      df = pd.concat([df,average_score], ignore_index=True)

  print('All precedure ends, YAY')

  return df

# %%
import pandas as pd

async def start_scraping_extend(df, anime_ids, min_anime_per_user):
  print('Endtend scraping from', len(anime_ids), 'animes, with minimum', min_anime_per_user, 'anime per user')
  for anime_id in anime_ids:
    names = await fetch_usernames(anime_id)
    for name in names:
      if name in df['username'].values:
        print('username already scraped, continuing................')
        continue
      anime_list = await fetch_anime_list(name)
      average_score = get_average_score(anime_list, name, min_anime_per_user)
      df = pd.concat([df,average_score], ignore_index=True)

  print('All precedure ends, YAY')

  return df

# %%
async def fetch_anime_ids(username):
  anime_ids = await fetch_anime_list(username)
  anime_ids = [entry['media']['id'] for entry in anime_ids]
  return anime_ids

# %%
anime_ids = await fetch_anime_ids('doddy')
len(anime_ids)
# Out:
# 256

# %%
df_2 = await start_scraping_extend(df, anime_ids[:50], 50)
# Out:
# Endtend scraping from 50 animes, with minimum 50 anime per user
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user kulos with 55 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user queermoons with 46 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user NextUniverse with 47 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user rebirthx with 80 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Kleinz with 65 of animes ................> Success
# Calculating average score by user chichisiwa with 99 of animes ................> Success
# Calculating average score by user Hikinnari with 7 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user satorublue with 36 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user withlovedese2 with 1 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Durabele with 98 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user hoang000147 with 30 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Hikinnari with 7 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user satorublue with 36 of animes ................> Aborted (Too few animes)
# Calculating average score by user RHN81 with 73 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user theebakedpotato with 18 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user DawnHibiki with 4 of animes ................> Aborted (Too few animes)
# Calculating average score by user Fractured with 2 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Yorshka with 0 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# Error: 404, {"errors":[{"message":"Private User","status":404,"locations":[{"line":3,"column":5}]}],"data":{"MediaListCollection":null}}
# Calculating average score by user CrimsonDemonLord with 0 of animes ................> Aborted (Too few animes)
# Calculating average score by user WillowDear with 13 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user michaohneel with 19 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user SuperVak with 85 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user YaBoi69420 with 91 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user TCR901 with 44 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Mildfury with 96 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Fractured with 2 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Kagamii with 37 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Pordexel with 98 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Goodie1857 with 46 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user ItzToxic with 97 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user chokuto78 with 81 of animes ................> Success
# Calculating average score by user michaohneel with 19 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Whatisausername with 82 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Willyumm with 39 of animes ................> Aborted (Too few animes)
# Calculating average score by user FugueStar with 90 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Krc with 21 of animes ................> Aborted (Too few animes)
# Calculating average score by user auraIinx with 33 of animes ................> Aborted (Too few animes)
# Calculating average score by user VernonGroubitz with 6 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Orangekid12 with 96 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Error: 404, {"errors":[{"message":"Private User","status":404,"locations":[{"line":3,"column":5}]}],"data":{"MediaListCollection":null}}
# Calculating average score by user DeepEyes95 with 0 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Rate limit exceeded while fetching usernames, Sleeping rn
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user aquelesousa with 71 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user raulzitosvm with 75 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user miwagrr with 33 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user chaka with 22 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user doodlemancy with 10 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user catboysociety with 67 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Kalladry with 52 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user NL3SS with 0 of animes ................> Aborted (Too few animes)
# Calculating average score by user NocturneRyan with 33 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user empanadatun with 74 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user axkemi with 82 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user AltoRoark with 73 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Heisenburger with 80 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user BillWoods with 58 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user chinesepro with 34 of animes ................> Aborted (Too few animes)
# Calculating average score by user BriForABri with 14 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user poonanimanny with 96 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user kalopsiaaaa with 50 of animes ................> Success
# Calculating average score by user rp with 62 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user chinesepro with 34 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user SolidSssnake with 12 of animes ................> Aborted (Too few animes)
# Calculating average score by user BriForABri with 14 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user DeLift with 63 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user AkiFosu with 55 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user PlatinuMan with 71 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user SiegmAer with 19 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user SA0 with 75 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Axaco with 84 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user EthanOBoss with 96 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user emnesoi with 66 of animes ................> Success
# username already scraped, continuing................
# Rate limit exceeded while fetching anime list, Sleeping rn
# Calculating average score by user SilverxProd with 56 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Entrylevelweebfrom22 with 58 of animes ................> Success
# Calculating average score by user isahbellah with 75 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Miposky with 43 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Error: 404, {"errors":[{"message":"Private User","status":404,"locations":[{"line":3,"column":5}]}],"data":{"MediaListCollection":null}}
# Calculating average score by user Chizuo with 0 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user AshVolcano with 96 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user inductionstove with 18 of animes ................> Aborted (Too few animes)
# Calculating average score by user Ghoul987 with 89 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user chinesepro with 34 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user necrotoddler with 61 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user sirobsidian with 23 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user SnovyTimmy with 20 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Leorion with 91 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user Sabischan with 91 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user de4th with 642 of animes ................> Success
# Calculating average score by user CryoStrider with 15 of animes ................> Aborted (Too few animes)
# Calculating average score by user kariohn with 90 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user Honyopenyoko with 47 of animes ................> Aborted (Too few animes)
# Calculating average score by user PhosPhossu with 499 of animes ................> Success
# Calculating average score by user deadscream with 448 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user JakeTitan with 208 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user bakesupreme with 51 of animes ................> Success
# Calculating average score by user Regime with 199 of animes ................> Success
# Calculating average score by user niheii with 355 of animes ................> Success
# Calculating average score by user SwagPuncher with 81 of animes ................> Success
# Calculating average score by user ProperPsycho with 77 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user CookieFrog with 73 of animes ................> Success
# Calculating average score by user TheBirdOfHermes with 437 of animes ................> Success
# Calculating average score by user Coolgu275 with 98 of animes ................> Success
# Rate limit exceeded while fetching anime list, Sleeping rn
# Calculating average score by user melocoton with 97 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user noasty with 62 of animes ................> Success
# Calculating average score by user llorando with 423 of animes ................> Success
# Calculating average score by user setok with 85 of animes ................> Success
# Calculating average score by user Leonardok with 186 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user randombluetoad with 34 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user Stuwbin with 34 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user biogundam with 85 of animes ................> Success
# Calculating average score by user animebeginner731 with 15 of animes ................> Aborted (Too few animes)
# Calculating average score by user Zuneee with 445 of animes ................> Success
# Calculating average score by user FSKULL1995 with 405 of animes ................> Success
# Calculating average score by user DragonDaddie with 76 of animes ................> Success
# Calculating average score by user LobotomyKaisen with 284 of animes ................> Success
# Calculating average score by user Storm9691 with 1518 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user DorkAssJC with 437 of animes ................> Success
# Calculating average score by user Chikaraa with 632 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user mistythewitch with 266 of animes ................> Success
# Calculating average score by user siddhant26 with 52 of animes ................> Success
# Calculating average score by user ZzKolin with 200 of animes ................> Success
# Calculating average score by user Sigsig with 37 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user MankoMan with 8 of animes ................> Aborted (Too few animes)
# username already scraped, continuing................
# Calculating average score by user DarkMIR4GE with 532 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user Aliferous with 104 of animes ................> Success
# Calculating average score by user Scathachthighs831 with 203 of animes ................> Success
# Calculating average score by user Welbi with 11 of animes ................> Aborted (Too few animes)
# Calculating average score by user Waqas2kk with 131 of animes ................> Success
# Calculating average score by user Static27o with 94 of animes ................> Success
# Calculating average score by user Axisrocks with 31 of animes ................> Aborted (Too few animes)
# Calculating average score by user Rorroe with 89 of animes ................> Success
# Calculating average score by user yuureivt with 194 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user KingofLaziness with 241 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# username already scraped, continuing................
# Calculating average score by user notpearitspeer with 210 of animes ................> Success
# username already scraped, continuing................
# Calculating average score by user Cocko with 149 of animes ................> Success
# username already scraped, continuing................
# username already scraped, continuing................
# All precedure ends, YAY

# %%
df.head(20)

# %%
df_2.to_csv('anilist-users-list.csv', index=False)
